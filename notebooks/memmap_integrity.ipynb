# %%
import torch
import polars as pl
import numpy as np

# %%
x  = torch.tensor(np.load('../data/01_processed/ssl_sets/ob007.memmap/shard_05922.npy'))
mask = ~x[...,-1].bool()

# %%
seq = x[:, :, 0][mask].flatten()
seq_df = pl.DataFrame({'seq':seq})
seq_df["seq"].value_counts(sort=True, normalize=True)
# Out:
# shape: (4, 2)
# ┌─────┬────────────┐
# │ seq ┆ proportion │
# │ --- ┆ ---        │
# │ f32 ┆ f64        │
# ╞═════╪════════════╡
# │ 0.0 ┆ 0.283008   │
# │ 3.0 ┆ 0.283008   │
# │ 1.0 ┆ 0.216992   │
# │ 2.0 ┆ 0.216992   │
# └─────┴────────────┘

# %%
mask.bool()
# Out:
# tensor([[False, False, False,  ..., False, False, False],
#         [False, False, False,  ..., False, False, False],
#         [False, False, False,  ..., False, False, False],
#         ...,
#         [False, False, False,  ..., False, False, False],
#         [False, False, False,  ...,  True,  True,  True],
#         [False, False, False,  ...,  True,  True,  True]])
