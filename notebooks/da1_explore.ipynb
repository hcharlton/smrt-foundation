# %%
import polars as pl
from smrt_foundation.dataset import SCHEMA

# %%
final_schema = {k: v for k, v in SCHEMA.items()}
final_schema
# Out:
# {'read_name': String,
#  'read_pos': UInt32,
#  'seq': List(UInt8),
#  'qual': List(UInt8),
#  'np': UInt8,
#  'sm': List(UInt8),
#  'sx': List(UInt8),
#  'fi': List(UInt8),
#  'fp': List(UInt8),
#  'ri': List(UInt8),
#  'rp': List(UInt8)}

# %%
q = (
    pl.scan_parquet('../data/01_processed/ssl_sets/da1.parquet')
    .head(100)
)
df = q.collect()

# %%
from smrt_foundation.utils import parse_schema, parse_yaml
config = parse_yaml('../smrt_foundation/config.yaml')
print(config['data']['schema'])
schema = parse_schema(config['data']['schema'])
print(schema)
# Out:
# {'read_name': 'pl.String', 'read_pos': 'pl.UInt32', 'seq': 'List(UInt8)', 'qual': 'List(UInt8)', 'np': 'UInt8', 'sm': 'List(UInt8)', 'sx': 'List(UInt8)', 'fi': 'List(UInt8)', 'fp': 'List(UInt8)', 'ri': 'List(UInt8)', 'rp': 'List(UInt8)'}
# {'read_name': String, 'read_pos': UInt32, 'seq': List(UInt8), 'qual': List(UInt8), 'np': UInt8, 'sm': List(UInt8), 'sx': List(UInt8), 'fi': List(UInt8), 'fp': List(UInt8), 'ri': List(UInt8), 'rp': List(UInt8)}

# %%
pl.read_parquet('../data/01_processed/ssl_sets/da1.parquet', schema = schema)
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 pl.read_parquet('../data/01_processed/ssl_sets/da1.parquet', schema = schema)
#
# File ~/miniforge3/envs/smrt-foundation/lib/python3.12/site-packages/polars/_utils/deprecation.py:128, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     123 @wraps(function)
#     124 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     125     _rename_keyword_argument(
#     126         old_name, new_name, kwargs, function.__qualname__, version
#     127     )
# --> 128     return function(*args, **kwargs)
#
# File ~/miniforge3/envs/smrt-foundation/lib/python3.12/site-packages/polars/_utils/deprecation.py:128, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     123 @wraps(function)
# ...

# %%
df['seq'][0].to_list()
# Out:
# [0,
#  3,
#  3,
#  1,
#  1,
#  0,
#  3,
#  0,
#  0,
#  2,
#  2,
#  2,
#  0,
#  2,
#  0,
#  0,
#  0,
#  3,
#  3,
#  0,
#  2,
#  1,
#  1,
#  0,
#  0,
#  0,
#  0,
#  1,
#  0,
#  0,
#  0,
#  2,
#  2,
#  2,
#  3,
#  1,
#  3,
#  2,
#  1,
#  0,
#  2,
#  2,
#  1,
#  1,
#  1,
#  1,
#  0,
#  3,
#  2,
#  1,
#  0,
#  0,
#  2,
#  3,
#  1,
#  1,
#  0,
#  0,
#  0,
#  0,
#  1,
#  1,
#  1,
#  2,
#  0,
#  1,
#  0,
#  0,
#  2,
#  2,
#  1,
#  0,
#  2,
#  3,
#  1,
#  0,
#  3,
#  3,
#  0,
#  0,
#  0,
#  3,
#  1,
#  3,
#  3,
#  0,
#  0,
#  2,
#  2,
#  1,
#  3,
#  1,
#  3,
#  2,
#  0,
#  0,
#  0,
#  1,
#  0,
#  0,
#  3,
#  1,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  2,
#  0,
#  1,
#  1,
#  3,
#  1,
#  0,
#  3,
#  1,
#  3,
#  1,
#  3,
#  1,
#  0,
#  1,
#  2,
#  3,
#  1,
#  1,
#  0,
#  2,
#  0,
#  2,
#  1,
#  0,
#  3,
#  0,
#  1,
#  3,
#  2,
#  0,
#  3,
#  2,
#  1,
#  0,
#  0,
#  3,
#  0,
#  3,
#  1,
#  3,
#  2,
#  2,
#  2,
#  1,
#  3,
#  1,
#  1,
#  1,
#  0,
#  3,
#  2,
#  0,
#  2,
#  1,
#  3,
#  3,
#  3,
# ...
